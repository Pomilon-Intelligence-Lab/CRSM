# %%
# !git clone https://github.com/Pomilon/CRSM.git
# %cd CRSM
# !pip install -e .

# %%
# !python scripts/download_wikitext.py
# !python scripts/bootstrap_traces.py

# %%
# !python scripts/train_full_crsm.py \
    --config configs/baseline_170m.json \
    --output-dir experiments/baseline_170m \
    --traces-path data/train_traces.jsonl
