# %% [markdown]
# # CRSM Cloud Training: Stage 2 (Dynamics)
#
# This notebook trains the Latent Dynamics Model (System 2 Subconscious).

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/Pomilon-Intelligence-Lab/crsm.git
# %cd crsm
# !pip install -r requirements.txt
# !pip install -e .

# %%
# Load Stage 1 Checkpoint
# !mkdir -p experiments/stage_1
# !cp /content/drive/MyDrive/crsm_experiments/stage_1/backbone_final.pt experiments/stage_1/

# %%
# !python scripts/training/stage_2_dynamics.py

# %%
# !cp experiments/stage_2/dynamics_final.pt /content/drive/MyDrive/crsm_experiments/stage_2/
