# %% [markdown]
# # CRSM Cloud Training: Stage 3 (Value Head)
#
# This notebook trains the Value Head using offline Expert Iteration.

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/Pomilon-Intelligence-Lab/crsm.git
# %cd crsm
# !pip install -r requirements.txt
# !pip install -e .

# %%
# Load Stage 1 & 2 Checkpoints
# !mkdir -p experiments/stage_1 experiments/stage_2
# !cp /content/drive/MyDrive/crsm_experiments/stage_1/backbone_final.pt experiments/stage_1/
# !cp /content/drive/MyDrive/crsm_experiments/stage_2/dynamics_final.pt experiments/stage_2/

# %%
# !python scripts/training/stage_3_value_head.py

# %%
# !cp experiments/stage_3/crsm_v1_complete.pt /content/drive/MyDrive/crsm_experiments/stage_3/
